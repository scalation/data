# %%
import pandas as pd

# %%
scalation_data = pd.read_csv("02a-jhu_2022-11-18-05-14-54.csv")
scalation_data.head()
# Out:
#          Date State      Lat     Long_  Confirmed  Deaths  Recovered  Active  \
# 0  2020-04-12    AK  61.3707 -152.4044        272       8       66.0   198.0
# 1  2020-04-13    AK  61.3707 -152.4044        277       8       85.0   184.0
# 2  2020-04-14    AK  61.3707 -152.4044        285       9       98.0   178.0
# 3  2020-04-15    AK  61.3707 -152.4044        293       9      106.0   178.0
# 4  2020-04-16    AK  61.3707 -152.4044        300       9      110.0   181.0
#
#    FIPS  Incident_Rate  ...  Case_Fatality_Ratio         UID  ISO3  \
# 0   2.0      37.181581  ...                  0.0  84000002.0   USA
# 1   2.0      37.865066  ...                  0.0  84000002.0   USA
# 2   2.0      38.958642  ...                  0.0  84000002.0   USA
# 3   2.0      40.052218  ...                  0.0  84000002.0   USA
# 4   2.0      41.009097  ...                  0.0  84000002.0   USA
#
#    Testing_Rate Hospitalization_Rate  People_Tested  Mortality_Rate  \
# ...

# %%
scalation_data["FIPS"] = scalation_data["FIPS"].astype('int64').astype(str).str.zfill(2)

# %%
scalation_data.to_csv("02a-jhu_2022-11-18-05-14-54_v3.csv")
