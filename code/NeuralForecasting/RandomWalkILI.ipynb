# %%
from models.RandomWalk import RandomWalk

# %%
MO = '% WEIGHTED ILI'
#MO = 'OT'
N, mse, mae, smape = RandomWalk(file_name = 'datasets/illness/national_illness.csv', training_ratio = 0.8, horizon = 24, main_output = MO,
    normalization = False)
print("Test set metrics {}".format(MO))
print('N:{}, MSE:{}, MAE:{}, sMAPE:{}'.format(N, mse, mae, smape))
# Out:
# Test set metrics % WEIGHTED ILI
# N:170, MSE:10.046326107920576, MAE:2.4726199411764704, sMAPE:89.49028066429378
