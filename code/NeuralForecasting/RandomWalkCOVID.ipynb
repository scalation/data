# %%
from models.RandomWalk import RandomWalk

# %%
MO = 'new_deaths'
N, mse, mae, smape = RandomWalk(file_name = 'datasets/covid/covid_19_weekly.csv',
                                training_ratio = 0.5, horizon = 1, main_output = MO,
                                normalization = False)
print("Test set metrics {}".format(MO))
print('N:{}, MSE:{}, MAE:{}, sMAPE:{}'.format(N, mse, mae, smape))
# Out:
# Test set metrics new_deaths
# N:85, MSE:1390704.8588235294, MAE:791.2823529411764, sMAPE:15.47922296732982

# %%
Test set metrics new_deaths
N:85, MSE:1390704.8588235294, MAE:791.2823529411764, sMAPE:15.47922296732982
                
Test set metrics new_deaths
N:84, MSE:3330225.5833333335, MAE:1144.0595238095239, sMAPE:19.768575488302147
                
Test set metrics new_deaths
N:83, MSE:5927379.156626506, MAE:1491.0361445783133, sMAPE:25.016831104514274
                
Test set metrics new_deaths
N:82, MSE:9274645.780487806, MAE:1821.8292682926829, sMAPE:30.11031037716555
# Out:
#   Cell In[13], line 1
#     Test set metrics new_deaths
#          ^
# SyntaxError: invalid syntax
